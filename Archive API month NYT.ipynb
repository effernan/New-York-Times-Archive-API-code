# %% [markdown]
# # New York Times API ARCHIVE Code
#
# Elena Fernandez Fernandez

# %% [markdown]
# ## Sources:
# * https://github.com/rochelleterman/scrape-interwebz/blob/master/1_APIs/3_api_workbook.ipynb
# * https://medium.com/@danalindquist/using-new-york-times-api-and-jq-to-collect-news-data-a5f386c7237b
# * https://stackabuse.com/saving-text-json-and-csv-to-a-file-in-python/

# %% [markdown]
# #### 1. Import libraries

# %%
import requests
import json
from __future__ import division
import csv

# %% [markdown]
# #### 2. Constructing API request
#
# * It is required that you get your own key here: https://developer.nytimes.com/

# %%
your_key = " " ## write your own key here

url = "https://api.nytimes.com/svc/archive/v1/1910/1.json?api-key=" + your_key ##you need to write the year and the month

r = requests.get(url)

json_data = r.json()

# %%
json_data
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'meta': {'hits': 8140},
#   'docs': [{'web_url': 'https://query.nytimes.com/gst/abstract.html?res=980DE3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '6',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'PHIL LEWIS LOSES CASE.; Brooklyn Club Not Required to Pay Salary Claimed.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdb45c1498b0d2420fc',
#     'word_count': 144,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E02E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'The Governments of the Far East occupied the attention of the American Political Science Association yesterday, several papers being read on the gradual awakening in that part of the world. The present status of political institutions in China, Ja...',
#     'lead_paragraph': 'The Governments of the Far East occupied the attention of the American Political Science Association yesterday, several papers being read on the gradual awakening in that part of the world. The present status of political institutions in China, Japan, and Korean was discussed, and some interesting light was thrown on the career of the late Empress Dowager.',
#     'print_page': '5',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "TORIANS HEAR OF CHINA'S AWAKENING; Leaders of Thought There Say Public Opinion Now Directs the Government.",
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdb45c1498b0d2420fd',
#     'word_count': 2393,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F0CE2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': 'BR9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'LAW OF THE RANGE.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdb45c1498b0d242104',
#     'word_count': 234,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9801E2DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'Sailing for Europe on Nov. 3, William Mitchell Lewis, Treasurer and General Manager of the Mitchell Motor Car Company, and Secretary G.V. Rogers purpose looking over the entire foreign field with the serious view of vigorously pushing into the Old...',
#     'lead_paragraph': 'Sailing for Europe on Nov. 3, William Mitchell Lewis, Treasurer and General Manager of the Mitchell Motor Car Company, and Secretary G.V. Rogers purpose looking over the entire foreign field with the serious view of vigorously pushing into the Old World as competitors of the pioneer makers of Europe.',
#     'print_page': 'AU11',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MITCHELL BRANCHING OUT.; Manager Lewis Touring Europe to Establish Foreign Agencies.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d24210b',
#     'word_count': 933,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D01E3DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'AFTER the ladies have returned to the drawing room, the cigars have been lighted, and you sip your coffee, I find that you may safely venture to discuss art, music, literature, science, and politics without danger of being considered a muff, a ped...',
#     'lead_paragraph': 'AFTER the ladies have returned to the drawing room, the cigars have been lighted, and you sip your coffee, I find that you may safely venture to discuss art, music, literature, science, and politics without danger of being considered a muff, a pedant, or a bore."',
#     'print_page': 'SM6',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Social Life in Washington and Why It Sometimes Fails to be What It Claims -- Cosmopolitan.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'By M.G. SECKENDORFF',
#      'person': [],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d242112',
#     'word_count': 3317,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E03E4DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': 'C4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'GERMAN AGRARIANS IN RAGE AT AMERICA; Organs Urge Government to Make No Concessions on imported Meat.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special Cable to THE NEW YORK TIMES',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d242117',
#     'word_count': 623,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9504E2DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'As with the introduction of the automobile into America some thirteen years ago there was expressed almost unanimous disfavor, so when the first taxicabs appeared in the metropolis public approval was not forthcoming in the beginning. This conditi...',
#     'lead_paragraph': 'As with the introduction of the automobile into America some thirteen years ago there was expressed almost unanimous disfavor, so when the first taxicabs appeared in the metropolis public approval was not forthcoming in the beginning. This condition quickly changed, and in a comparatively few months it was firmly demonstrated that the modern taxlcab, with its quick service and precise record of fares, was a much-needed innovation.',
#     'print_page': 'AU4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'TAXICAB SERVICE WELL REGULATED; Early Deficiencies and Irregularly ties Remedied and System Adopted to Protect Patrons.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'By E.S. PARTRIDGE',
#      'person': [{'firstname': 'E.',
#        'middlename': 'S.',
#        'lastname': 'PARTRIDGE',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d242119',
#     'word_count': 725,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=950DE4DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': 'S1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "TWO-YEAR-OLDS' FIRST RACE.; Tallahassee Beats Fourteen Other Youngsters at Jacksonville.",
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d24211b',
#     'word_count': 404,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9800E4DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'LONDON, Jan. 1. -- The inadvisability of interfering in a family quarrel has been demonstrated by August Busck of the Smithsonian Institution of Washington, who sent to The London Times this week a contribution to the controversy which has been go...',
#     'lead_paragraph': 'LONDON, Jan. 1. -- The inadvisability of interfering in a family quarrel has been demonstrated by August Busck of the Smithsonian Institution of Washington, who sent to The London Times this week a contribution to the controversy which has been going on in the columns of that journal with regard to the separation of the Natural History Museum from the British Museum.',
#     'print_page': 'C3',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'RESENTS AMERICAN CRITICISM; Sir Edwin Lankester Answers August Busck on Value of a Collection.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special Cable to THE NEW YORK TIMES',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d24211e',
#     'word_count': 443,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9507E0DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': 'The arrangements on the part of the managements of great business enterprises and of banking institutions in the financial district incident to the distribution of the enormous year-end interest and dividend payments explain the barrenness in a ne...',
#     'lead_paragraph': 'The arrangements on the part of the managements of great business enterprises and of banking institutions in the financial district incident to the distribution of the enormous year-end interest and dividend payments explain the barrenness in a news way of the business week which closed on Friday last.',
#     'print_page': '12',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'THE FINANCIAL SITUATION.; THE MARKETS OF EUROPE',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d242122',
#     'word_count': 1300,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B06E1DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': 'The Newark police are investigating the deaths of William Schwan and his sister-in-law, Mrs. Sophia Frick, the former 72 years old, and the latter only nine years her junior, whose deaths late on Saturday night were supposed at first by the police...',
#     'lead_paragraph': 'The Newark police are investigating the deaths of William Schwan and his sister-in-law, Mrs. Sophia Frick, the former 72 years old, and the latter only nine years her junior, whose deaths late on Saturday night were supposed at first by the police to be due to apoplexy. Both, it has developed since, died of bullet wounds, fired, according to Mrs. Schwan, widow of the dead man, by her husband.',
#     'print_page': '2',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'AGED WOMAN SLAIN; BROTHER-IN-LAW, TOO; Murder and Suicide, Says the Widow, of a Double Tragedy in Newark.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc04fdc45c1498b0d242124',
#     'word_count': 696,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9901E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'It was a rousing salute which the infant stranger, 1910, received last night at all the hotels and restaurants from the Battery to the Bronx. At the entrance of the precocious youngster, on the last stroke of twelve, thousands of Dopping champagne...',
#     'lead_paragraph': 'It was a rousing salute which the infant stranger, 1910, received last night at all the hotels and restaurants from the Battery to the Bronx. At the entrance of the precocious youngster, on the last stroke of twelve, thousands of Dopping champagne corks let go their ceaseless cannonading, glasses clinked in toasts to the advent of the New Year.',
#     'print_page': '2',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "HOTELS OVERFLOW WITH JOYFUL GUESTS; A Girl, Like a Bird, Flies from at Clock to Startle New Year's Diners at One.",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'NEW YEAR',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject', 'value': 'NEW YEAR', 'rank': 0, 'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05ce945c1498b0d27d4fc',
#     'word_count': 1741,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9501E1DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': 'Abraham Abraham of the firm of Abraham  Strauss believes that too much money is being expended by the city for small parks at the expense or traction facilities. In an address last week at the Brooklyn Club, during the celebration of the opening o...',
#     'lead_paragraph': 'Abraham Abraham of the firm of Abraham Strauss believes that too much money is being expended by the city for small parks at the expense or traction facilities. In an address last week at the Brooklyn Club, during the celebration of the opening of the Manhattan Bridge, Mr. Abraham said that the new administration would have an opportunity to solve the tangled traction problem, since the debt limitation was no longer an obstacle.',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'WOULD THIN CROWDED AREAS.; Abraham Abraham Calls for Fewer Parks and More Suburb Transportation.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'NEW YORK CITY',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject',
#       'value': 'PARKS AND PLAYGROUNDS',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject',
#       'value': 'TRANSIT SERVICES',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05ce945c1498b0d27d514',
#     'word_count': 287,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9501E5DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'Frank K. Sturgis, President, and James C. Young, secretary and treasurer of the Madison Square Garden Company, yesterday denied as absolutely untrue and unfounded a report published in one of the morning papers to the effect that Madison Square Ga...',
#     'lead_paragraph': 'Frank K. Sturgis, President, and James C. Young, secretary and treasurer of the Madison Square Garden Company, yesterday denied as absolutely untrue and unfounded a report published in one of the morning papers to the effect that Madison Square Garden had passed into the hands of a syndicate of capitalists for $3,900,000, and that after the formal acquiring of the property on July 20, 1910, a modern twenty-story office building would be erected there.',
#     'print_page': '9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MADISON SQ. GARDEN NOT SOLD; Sturgis and Others Say a Contrary Re- port Is Wholly Unfounded.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'MADISON SQUARE GARDEN (NYC)',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05cea45c1498b0d27d6d4',
#     'word_count': 300,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B01E5DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': "A series or puppet tableaux to illustrate American history from the time of Columbus down to the present date is being set up at the Children's Museum in Kingston Park, Brooklyn. At present the groups completed carry the children down to the Revol...",
#     'lead_paragraph': "A series or puppet tableaux to illustrate American history from the time of Columbus down to the present date is being set up at the Children's Museum in Kingston Park, Brooklyn. At present the groups completed carry the children down to the Revolutionary period, and the other tableaux will be added as soon as the finishing touches have been given them.",
#     'print_page': '9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "PUPPET TABLEAUX TO TEACH HISTORY; Children's Museum Hits on New Plan to Make That Study Interesting to the Young. ALL PERIODS REPRESENTED Scenes Complete in Every Detail Show Progress of America from the Earliest Days Down to the Present.",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'HISTORY',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05ce845c1498b0d27d2ee',
#     'word_count': 1368,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D06E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '10',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Stocks Irregular and Active -- Call Money Rates, 5 1/2@6 1/4 Per Cent.; BANKS' SURPLUS REDUCED",
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05ce145c1498b0d27c746',
#     'word_count': 479,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9901E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '11',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Article 2 -- No Title',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05ce145c1498b0d27c747',
#     'word_count': 17,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=990CE3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'New York can ill afford to lose SPENCER TRASK. He was an influential and useful citizen, associated with many large enterprises, the initiator of many movements for the public good, an energetic, broad-minded, kind-hearted man whose interests were...',
#     'lead_paragraph': 'New York can ill afford to lose SPENCER TRASK. He was an influential and useful citizen, associated with many large enterprises, the initiator of many movements for the public good, an energetic, broad-minded, kind-hearted man whose interests were greatly varied.',
#     'print_page': '8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'SPENCER TRASK.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Editorial',
#     '_id': '4fc05ce145c1498b0d27c748',
#     'word_count': 329,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9400E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '3',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'GREENHUT GIFT TO PEORIA.; G.A.R. Memorial Hall Dedicated by Capt. J.B. Greenhut.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special to The New York Times',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc05ce145c1498b0d27c749',
#     'word_count': 180,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D02E1DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Inventory for Corporation Tax.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'JAMES SMITH',
#      'person': [{'firstname': 'James',
#        'middlename': None,
#        'lastname': 'SMITH',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Letter',
#     '_id': '4fc05ce145c1498b0d27c762',
#     'word_count': 140,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9503E1DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '7',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Bobsled Races at Caldwell.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special to The New York Times',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc05ce145c1498b0d27c764',
#     'word_count': 165,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D04E1DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Front Page 2 -- No Title',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Front Page',
#     '_id': '4fc05ce145c1498b0d27c765',
#     'word_count': 30,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9906E2DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'Vincenzo Lancia of Turin, Italy, maker of the car of that name, arrived in New York in time for the opening of the A.M.C.M.A. Show. He is coming here from London, where he attended the Olympia exhibition. He will remain here for the automobile sho...',
#     'lead_paragraph': 'Vincenzo Lancia of Turin, Italy, maker of the car of that name, arrived in New York in time for the opening of the A.M.C.M.A. Show. He is coming here from London, where he attended the Olympia exhibition. He will remain here for the automobile show season, and will then visit several of the factories of this country.',
#     'print_page': 'AU8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'FOREIGN CARS SHOWN.; Exhibition of Salon Models Attract At- tention at Palace Show.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc05b1245c1498b0d273e2f',
#     'word_count': 637,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9402E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'The Marathon run as an amateur sporting event was held up before the critical eye of the Society of Directors of Physical Education in Colleges at its meeting at Columbia University yesterday, and the most careful and painstaking data ever collect...',
#     'lead_paragraph': 'The Marathon run as an amateur sporting event was held up before the critical eye of the Society of Directors of Physical Education in Colleges at its meeting at Columbia University yesterday, and the most careful and painstaking data ever collected on the physical condition of long-distance runners were placed before the conference by Dr. W.L. Savage, Dr. Joseph H. Barach, and Dr. John D. Boyce.',
#     'print_page': '5',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'CONDEMNS MARATHONS.; Dr. Savage Says 26 Miies Is Too Long a Grind for Amateurs.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'PHYSICAL EDUCATION AND TRAINING',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject',
#       'value': 'TOBACCO AND TOBACCO PRODUCTS',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc0576645c1498b0d2641ef',
#     'word_count': 466,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9403E5DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'The movement described in our columns yesterday morning on the authority of The Church News may have a very considerable influence on the social and moral life of the country. It is a movement begun on the suggestion of some active Roman Catholic ...',
#     'lead_paragraph': 'The movement described in our columns yesterday morning on the authority of The Church News may have a very considerable influence on the social and moral life of the country. It is a movement begun on the suggestion of some active Roman Catholic priests from the West to secure co-operation between the Catholic and Protestant clergy and their respective churches in promoting religion and morality.',
#     'print_page': '12',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A DEFENSIVE RELIGIOUS ALLIANCE.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'RELIGION AND CHURCHES',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Editorial',
#     '_id': '4fc0576745c1498b0d26435c',
#     'word_count': 503,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D0CE4DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': 'S1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Ice Yacht Races Again Postponed.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special to The New York Times',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc0575f45c1498b0d26368e',
#     'word_count': 132,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F06E3DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'ALL things work together for high prices to people who have to eat. Everywhere there is a boosting tendency; nowhere is there any counteracting tendency which would help in the least to depress prices.  ',
#     'lead_paragraph': 'ALL things work together for high prices to people who have to eat. Everywhere there is a boosting tendency; nowhere is there any counteracting tendency which would help in the least to depress prices.',
#     'print_page': 'SM2',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Why "Everything Costs So Much."; How a Rise in the Price of One Commodity Forces Up Others.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc0575f45c1498b0d263690',
#     'word_count': 2429,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9903E3DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'IT will be extremely interesting to the art lovers of this city to learn that the collection of the late Cyrus J. Lawrence is to be sold next month at the American Art Galleries. Mr. Lawrence was a collector whose taste and judgment were of the hi...',
#     'lead_paragraph': 'IT will be extremely interesting to the art lovers of this city to learn that the collection of the late Cyrus J. Lawrence is to be sold next month at the American Art Galleries. Mr. Lawrence was a collector whose taste and judgment were of the highest order, alike sound and free, repelled by the second rate in execution, conception, or design, delicately conservative, yet hospitable to new ideas and modern forms.',
#     'print_page': 'SM14',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'The Fine Collection of the Late Cyrus J. Lawrence to be Sold at Auction Next Month.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc0575f45c1498b0d263691',
#     'word_count': 718,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E07E4DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'faculty opposes erecting bldgs on site',
#     'print_page': '18',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'YALE FACULTY REBEL AT NEW CAMPUS IDEA; Oppose Erection of Buildings on Hillhouse Estate, the $650,- 000 Gift of Mrs. Sage.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'YALE UNIVERSITY',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special to The New York Times',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc058c945c1498b0d26a658',
#     'word_count': 1294,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D01E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'Dr P Lowell s on new canals on Mars, Amer Assn for Advancement of Science',
#     'print_page': '1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MARS BUILDING NEW CANALS.; Prof. Percival Lowell Describes New Work to the American Association.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'SCIENCE, AMERICAN ASSN FOR THE ADVANCEMENT OF',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject', 'value': 'ASTRONOMY', 'rank': 0, 'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Front Page',
#     '_id': '4fc058c945c1498b0d26a65c',
#     'word_count': 248,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E0CE3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'With his formal installation to-day, Mr. GAYNOR will enter on a term of four years as Mayor of New York, with more Dower than the Chief Magistrate of any city in the world, with many difficulties to overcome, but also with some great opportunities...',
#     'lead_paragraph': 'With his formal installation to-day, Mr. GAYNOR will enter on a term of four years as Mayor of New York, with more Dower than the Chief Magistrate of any city in the world, with many difficulties to overcome, but also with some great opportunities, which bring a corresponding responsibility.',
#     'print_page': '8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MAYOR GAYNOR.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'NEW YORK CITY',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject', 'value': 'LABOR', 'rank': 0, 'major': None},
#      {'name': 'subject',
#       'value': 'POLITICS AND GOVERNMENT',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Editorial',
#     '_id': '4fc058c945c1498b0d26a665',
#     'word_count': 814,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9805E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'The art collection of the late Theron R. Butler has just been placed on view at the American Art Galleries prior to its sale at Mendelssohn Hall, Friday evening, Jan. 7.',
#     'lead_paragraph': 'The art collection of the late Theron R. Butler has just been placed on view at the American Art Galleries prior to its sale at Mendelssohn Hall, Friday evening, Jan. 7.',
#     'print_page': '8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'THERON R. BUTLER PICTURES ON VIEW; Fnench Painter, Girard, Represented by a Curious Panorama of Street Life in Pairs.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'ART',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Editorial',
#     '_id': '4fc058c945c1498b0d26a69f',
#     'word_count': 884,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=940DE5DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': 'L Tetrazzini recovers from recent illness, reappears on Manhattan Opera stage',
#     'print_page': '13',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'D\'ALVAREZ IN "HERODIADE."; Newcomer in Cast Makes Beautiful Picture as Herodias and Sings Well.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'OPERA',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject', 'value': 'GENERAL', 'rank': 0, 'major': None}],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc058c945c1498b0d26a6a0',
#     'word_count': 245,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C0DE1DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': 'To the Editor of The New York Times: The most important recent political news from China is the degradation of Tuan Fang, Viceroy of Chill Province, who was generally regarded by foreigners as the most able of the Chinese high-class officials, and...',
#     'lead_paragraph': 'To the Editor of The New York Times: The most important recent political news from China is the degradation of Tuan Fang, Viceroy of Chill Province, who was generally regarded by foreigners as the most able of the Chinese high-class officials, and who was once looked upon as the future leader in Peking politics.',
#     'print_page': '8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "TUAN FANG'S DEGRADATION.; A Woman's Influence and a Selfish Dynasty Responsible for It.",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'CHINA',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'GEORGE TRUMBULL LADD',
#      'person': [{'firstname': 'George',
#        'middlename': 'Trumbull',
#        'lastname': 'LADD',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Letter',
#     '_id': '4fc058c745c1498b0d26a35e',
#     'word_count': 903,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A06E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'Arthur Hammerstein told a TIMES reporter last evening that negotiations were under way between himself and the Metropolitan Opera Company, whereby it might be possible for his father to join the Directorate of the Metropolitan company, becoming th...',
#     'lead_paragraph': 'Arthur Hammerstein told a TIMES reporter last evening that negotiations were under way between himself and the Metropolitan Opera Company, whereby it might be possible for his father to join the Directorate of the Metropolitan company, becoming the head of the French opera forces there, and taking with him not only his French but his Italian company.',
#     'print_page': '1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MERGER OF OPERAS UNDER NEGOTIATION; Arthur Hammerstein Tells of a Proposal, Now Being Discussed, to Unite with Metropolitan.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'OPERA',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject', 'value': 'GENERAL', 'rank': 0, 'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Front Page',
#     '_id': '4fc058c745c1498b0d26a3ba',
#     'word_count': 1154,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D0CE3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': "A Clue to Dr. Cook's Whereabouts? From present indications, Dr. Cook has only to remain a little while longer in his present seclusion and he will pass altogether out of the public mind, perhaps to be recalled now and then with humorous appreciati...",
#     'lead_paragraph': "A Clue to Dr. Cook's Whereabouts? From present indications, Dr. Cook has only to remain a little while longer in his present seclusion and he will pass altogether out of the public mind, perhaps to be recalled now and then with humorous appreciation as the man who played a colossal joke on the world and made a lot of money out of its credulity.",
#     'print_page': '8',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'TOPICS OF THE TIMES.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'FRUIT AND VEGETABLES',
#       'rank': 0,
#       'major': None},
#      {'name': 'subject', 'value': 'MARRIAGES', 'rank': 0, 'major': None}],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Editorial',
#     '_id': '4fc058c745c1498b0d26a477',
#     'word_count': 1141,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D04E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Eugene Corry Gordon.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Obituary',
#     '_id': '4fc058be45c1498b0d269889',
#     'word_count': 883,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E07E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': 'PHILADELPHIA, Dec. 31 -- The last day of 1909 saw a repetition of the same stock market tactics which have grown so familiar during the past year -- an active bidding up of a few issues, while others hung heavy with considerable liquidation under ...',
#     'lead_paragraph': 'PHILADELPHIA, Dec. 31 -- The last day of 1909 saw a repetition of the same stock market tactics which have grown so familiar during the past year -- an active bidding up of a few issues, while others hung heavy with considerable liquidation under the cover of the conspicuous advances. Rock Island jumped $2 at the opening and remained strong all day, although there was heavy realizing on speculative holdings at times.',
#     'print_page': '10',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'PHILADELPHIA PRICES.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special to The New York Times',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc058be45c1498b0d26988b',
#     'word_count': 410,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9906E3DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'CHICAGO JOB FOR NEW YORKER; Supt. Fetherston of Richmond to Look After Chicago Streets at $5,500 Salary.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special to The New York Times',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Front Page',
#     '_id': '4fc058be45c1498b0d26988d',
#     'word_count': 203,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C04E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MRS. HUGH K. NORMAN WEDS.; Married to William Kendall of New York at Worcester, Mass.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Marriage Announcement',
#     '_id': '4fc058be45c1498b0d26988e',
#     'word_count': 326,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9404E2DA1730E233A25752C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Marriage Announcement 1 -- No Title',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-01T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Marriage Announcement',
#     '_id': '4fc058be45c1498b0d26988f',
#     'word_count': 32,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=950CE4DD1139E333A25751C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': 'S1',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Dartmouth Beaten at Hockey.; Harry Hillman's Farewell Party.",
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-02T00:00:00Z',
#     'document_type': 'article',
# ...
#     'snippet': 'Schults, Levi, 99',
#     'print_page': '13',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Obituary 1 -- No Title',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'LONGEVITY',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Obituary',
#     '_id': '4fc058c845c1498b0d26a509',
#     'word_count': 2779,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F05EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': 'The battleship Texas, now out of commission, will become the training ship of the Massachusetts Naval Militia, if the plans of Secretary Meyer and the wishes of the Bay State militiamen are approved by Gov. Eben Draper of Massachusetts. Gov. Drape...',
#     'lead_paragraph': 'The battleship Texas, now out of commission, will become the training ship of the Massachusetts Naval Militia, if the plans of Secretary Meyer and the wishes of the Bay State militiamen are approved by Gov. Eben Draper of Massachusetts. Gov. Draper wrote the Navy Department that he preferred the cruiser Chicago, as he thought that the Texas might prove to be too large a proposition for his force to handle.',
#     'print_page': '2',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'TEXAS MAY BE MILITIA SHIP.; Government Has Offered "Hoodoo Warship" to Massachusetts Naval Men',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'UNITED STATES',
#       'rank': 0,
#       'major': None},
#      {'name': 'glocations',
#       'value': 'MASSACHUSETTS',
#       'rank': 0,
#       'major': None},
#      {'name': 'organizations',
#       'value': 'UNITED STATES NAVY',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc058c845c1498b0d26a534',
#     'word_count': 337,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E07EFDA1730E233A25756C0A9679C946196D6CF',
#     'snippet': 'party leaves Hoimi',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Roosevelt Party Leaves Hoimi.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'HUNTING AND TRAPPING',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-05T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc058c745c1498b0d26a35b',
#     'word_count': 24,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9B07EFDA1730E233A25756C0A9679C946196D6CF',
#     'snippet': 'Chapel built by Amer prisoners in Devonshire during war being rebuilt by Amers',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'AMERICANS RESTORE CHAPEL.; Originally Built in England by Prisoners in War of 1812.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'WAR OF 1812',
#       'rank': 0,
#       'major': None}],
#     'pub_date': '1910-01-05T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069f345c1498b0d2b9f23',
#     'word_count': 117,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C06E0DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '12',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'LONDON EXPECTS GOOD TIMES.; Money Rates Likely to Go Lower, Without Sluggishness in Market.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'byline': {'original': 'Special Cable to THE NEW YORK TIMES',
#      'person': [{'firstname': None,
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b8fde',
#     'word_count': 155,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C06EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '3',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'CHEER PEARY AT PORTLAND.; Explorer Lectures in Maine and Gets Cordial Greeting.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b8ff2',
#     'word_count': 72,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9C01E0DA1730E233A25750C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '15',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'THE COMMODITIES MARKETS.; Wheat Belt Under Good Snow Protec- tion -- Corn Firmly Held -- Cotton Of- ferings Readily Absorbed.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-03T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b8ff4',
#     'word_count': 1771,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E01E7DB1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '9',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'C.W. Murphy Makes a Denial.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b8ff7',
#     'word_count': 66,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=980CEEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '6',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'TWINS FALL IN TURN,; But Joseph Only Sprains His Ankle While Edward Was Killed.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b8ffc',
#     'word_count': 259,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F04EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '2',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Society of the Genesee to Dine.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b8ffd',
#     'word_count': 69,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E03EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': 'The police spent yesterday seeking Jimmy Kelly, an east side gang leader, who in they believe to be one or the men who entered Lyric Hall, in Sixth Avenue, near Forty-second Street, at 1:30 A. M. yesterday morning, when 300 men and women were danc...',
#     'lead_paragraph': 'The police spent yesterday seeking Jimmy Kelly, an east side gang leader, who in they believe to be one or the men who entered Lyric Hall, in Sixth Avenue, near Forty-second Street, at 1:30 A. M. yesterday morning, when 300 men and women were dancing, and fired the shots one of which struck Grace Foley, the nineteen-year-old girl who was takren to the New York Hospital.',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'GANG FIGHT STOPPED DANCE.; Police Think it Cause of Lyric Hall Shooting -- Girl Victim All Right.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b9004',
#     'word_count': 618,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9F00E7DB1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '10',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BRIGHTON STAKE ENTRIES.; Hildreth Names His Best Horses for Beach Racing Season.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b9006',
#     'word_count': 231,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9800EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': '20,000 MINERS IDLE.; Strike in Northumberland Results from Dispute Over New Law.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b9007',
#     'word_count': 60,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9904E7DB1539E433A25757C0A9679C946196D6CF',
#     'snippet': 'Charles W. Adams, according to the police an old-time confidence man, who was arrested when he was leaving the Broadway Central Hotel a few weeks ago with letters addressed to "James Thomas Southwick," and having to do with what is known as the Br...',
#     'lead_paragraph': 'Charles W. Adams, according to the police an old-time confidence man, who was arrested when he was leaving the Broadway Central Hotel a few weeks ago with letters addressed to "James Thomas Southwick," and having to do with what is known as the British Heir Swindle, appeared for examination yesterday before United States Commissioner Shields in the Federal Building.',
#     'print_page': '7',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'C.W. ADAMS\'S DEFENSE.; Contends He Was Merely Agent in Getting "British Heirs" Letters.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b900c',
#     'word_count': 277,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9D03EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': "Wealth brought no happiness to Frank McGarry, a retired policeman, and his wife a former servant girl, according to papers filed yesterday in her suit for separation. McGarry's two sons corroborate their father's statement that wealth turned their...",
#     'lead_paragraph': 'Wealth brought no happiness to Frank McGarry, a retired policeman, and his wife a former servant girl, according to papers filed yesterday in her suit for separation. McGarry\'s two sons corroborate their father\'s statement that wealth turned their stepmother\'s head and she became possessed of an "insane desire to amass" more wealth.',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "COULDN'T STAND PROSPERITY; Wealth Finally Breaks Up the Family of Frank McGarry, ex-Policeman.",
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b900f',
#     'word_count': 488,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9E01EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': 'Controller Prendergast started in the real business of taking over the Department of Finance yesterday by instituting changes in the office, which caused the old-timers in the department to wonder what would happen next.  ',
#     'lead_paragraph': 'Controller Prendergast started in the real business of taking over the Department of Finance yesterday by instituting changes in the office, which caused the old-timers in the department to wonder what would happen next.',
#     'print_page': '3',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "PRENDERGAST JARS CLERKS.; New Controller's Time Cards Gives the Department a Shock.",
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b9011',
#     'word_count': 379,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A00EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Article 3 -- No Title',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b9012',
#     'word_count': 91,
#     'score': 0},
#    {'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9901EEDC1539E433A25757C0A9679C946196D6CF',
#     'snippet': '',
#     'print_page': '4',
#     'blog': [],
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'CANNOT GET RID OF NEGRO.; Steamer Line Has Unwelcome Guest Deported from Two Countries.',
#      'kicker': '1',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1910-01-04T00:00:00Z',
#     'document_type': 'article',
#     'type_of_material': 'Article',
#     '_id': '4fc069e645c1498b0d2b9019',
#     'word_count': 165,
#     'score': 0},
#    ...]}}

# %%
response_text = r.text

# %%
data = json.loads(response_text)

# %%
print(data.keys())
# Out:
# dict_keys(['copyright', 'response'])

# %%
data['response'].keys()
# Out:
# dict_keys(['meta', 'docs'])

# %%
docs = data['response']['docs']

# %%
len(docs)
# Out:
# 8140

# %% [markdown]
# #### 3. Filter the information that we would like to have for our analysis

# %%
def format_articles(unformatted_docs):
    '''
    This function takes in a list of documents returned by the NYT api 
    and parses the documents into a list of dictionaries, 
    with 'id', 'header', and 'date' keys
    '''
    formatted = []
    for i in unformatted_docs:
        dic = {}
        dic['headline'] = i['headline']['main']
        dic['date'] = i['pub_date'] # cutting time of day.
        dic['snippet'] = i['snippet']
        formatted.append(dic)
    return(formatted)

# %%
all_formatted = format_articles(docs)

# %% [markdown]
# #### 4. Save the data into a CSV file

# %%
keys = all_formatted[1]
# writing the rest
with open('january1920.csv', 'w', encoding = 'utf-8') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_formatted)
